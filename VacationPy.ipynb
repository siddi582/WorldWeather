# %%
#Import the dependencies
import pandas as pd
import gmaps
import requests
#Import the API key
from config import g_key

# %%
#Store the CSV you saved created in part one into a DataFrame
city_data_df = pd.read_csv("weather_data/cities.csv")
city_data_df.head()
# Out:
#    City_ID       City Country                 Date      Lat       Lng  \
# 0        0  Hithadhoo      MV  2022-10-17 20:33:30  -0.6000   73.0833
# 1        1  Saskylakh      RU  2022-10-17 20:33:30  71.9167  114.0833
# 2        2   Victoria      HK  2022-10-17 20:32:04  22.2855  114.1577
# 3        3    Rikitea      PF  2022-10-17 20:33:30 -23.1203 -134.9692
# 4        4    Omaruru     NaN  2022-10-17 20:33:31 -21.4333   15.9333
#
#    Max Temp  Humidity  Cloudiness  Wind Speed
# 0     80.98        71         100        7.40
# 1      2.35        99          97        2.95
# 2     77.05        73         100       23.89
# 3     68.97        61           4       18.30
# 4     66.99        55           3        7.87

# %%
#Get the data types
city_data_df.dtypes
# Out:
# City_ID         int64
# City           object
# Country        object
# Date           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# dtype: object

# %% [markdown]
# # Create a Maximum Temperature Heatmap

# %%
#First tell gmaps to use API key and you need to configure gmaps to use it once
gmaps.configure(api_key=g_key)

# %% [markdown]
# #### Create Heatmap

# %%
#Get the maximum temperature
max_temp = city_data_df["Max Temp"]

temps = []

for temp in max_temp:
    temps.append(max(temp, 0))
    
# Get the latitude and longitude
locations = city_data_df[["Lat", "Lng"]]
    
# Assign the figure variable
fig = gmaps.figure()

# Assign the heatmap variable
heat_layer = gmaps.heatmap_layer(locations, weights=[max(temp, 0) for temp in max_temp])

# Add the heatmap layer
fig.add_layer(heat_layer)

# Call the figure to plot the data
fig

# Heatmap of temperature
# Get the latitude and longitude.
#locations = city_data_df[["Lat", "Lng"]]
# Get the maximum temperature.
#max_temp = city_data_df["Max Temp"]
# Assign the figure variable.
#fig = gmaps.figure()
# Assign the heatmap variable.
#heat_layer = gmaps.heatmap_layer(locations, weights=max_temp)
# Add the heatmap layer.
#fig.add_layer(heat_layer)
# Call the figure to plot the data.
#fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# # Creating a Percent Cloudiness Heatmap

# %%
#Heatmap of Percent Cloudiness
#Get the Latitude and Longitude
locations = city_data_df[["Lat", "Lng"]]

#Assign the variables so that percent cloudiness replace percent humidity 
clouds = city_data_df["Cloudiness"]

#Adjust variable
fig = gmaps.figure(center=(30.0, 31.0), zoom_level = 1.5)

#Assign the heatmap variable
heat_layer = gmaps.heatmap_layer(locations, weights=clouds, dissipating=False, max_intensity=300,
                                point_radius=4)
fig.add_layer(heat_layer)
#Call the figure to plot the data 

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# # Create a Wind Speed Heatmap

# %%
#so that wind speed replaces percent cloudiness 


#Get the Latitude and Longitude
locations = city_data_df[["Lat", "Lng"]]

#Assign the variables so that Wind Speed replaces percent Cloudiness 
wind = city_data_df["Wind Speed"]

#Adjust variable
fig = gmaps.figure(center=(30.0, 31.0), zoom_level = 1.5)

#Assign the heatmap variable
heat_layer = gmaps.heatmap_layer(locations, weights=clouds, dissipating=False, max_intensity=300,
                                point_radius=4)
fig.add_layer(heat_layer)
#Call the figure to plot the data 

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Your clients will enter their preferences. Your code will tell them where to travel. It's beautiful, simple, and just needs a few more lines of code to actually work.
# Ask the customer to add a minimum and maximum temperature value
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maxinum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 75
# What is the maxinum temperature you would like for your trip? 90

# %%
# Filter the dataset to find the cities that fit the criteria.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df.head(10)
# Out:
#     City_ID          City Country                 Date      Lat       Lng  \
# 0         0     Hithadhoo      MV  2022-10-17 20:33:30  -0.6000   73.0833
# 2         2      Victoria      HK  2022-10-17 20:32:04  22.2855  114.1577
# 5         5         Praya      CV  2022-10-17 20:33:31  14.9215  -23.5087
# 8         8        Atuona      PF  2022-10-17 20:33:32  -9.8000 -139.0333
# 9         9          Sann      PK  2022-10-17 20:33:32  26.0418   68.1378
# 11       11          Mana      GF  2022-10-17 20:33:33   5.6592  -53.7767
# 15       15        Faanui      PF  2022-10-17 20:33:34 -16.4833 -151.7500
# 27       27          Daru      PG  2022-10-17 20:33:38  -9.0763  143.2092
# 28       28  Texistepeque      SV  2022-10-17 20:33:38  14.1333  -89.5000
# 31       31         Kapaa      US  2022-10-17 20:33:39  22.0752 -159.3190
#
#     Max Temp  Humidity  Cloudiness  Wind Speed
# 0      80.98        71         100        7.40
# 2      77.05        73         100       23.89
# ...

# %%
#count the null values
preferred_cities_df.count()
# Out:
# City_ID       164
# City          164
# Country       164
# Date          164
# Lat           164
# Lng           164
# Max Temp      164
# Humidity      164
# Cloudiness    164
# Wind Speed    164
# dtype: int64

# %%
preferred_cities_df.notnull().sum()
# Out:
# City_ID       164
# City          164
# Country       164
# Date          164
# Lat           164
# Lng           164
# Max Temp      164
# Humidity      164
# Cloudiness    164
# Wind Speed    164
# dtype: int64

# %%
preferred_cities_df.isnull().sum()
# Out:
# City_ID       0
# City          0
# Country       0
# Date          0
# Lat           0
# Lng           0
# Max Temp      0
# Humidity      0
# Cloudiness    0
# Wind Speed    0
# dtype: int64

# %% [markdown]
# #### Conclusion: As shown there are no null values

# %% [markdown]
# # Map Vacation

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = preferred_cities_df[["City", "Country", "Max Temp", "Lat", "Lng"]].copy()
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#             City Country  Max Temp      Lat       Lng Hotel Name
# 0      Hithadhoo      MV     80.98  -0.6000   73.0833
# 2       Victoria      HK     77.05  22.2855  114.1577
# 5          Praya      CV     79.34  14.9215  -23.5087
# 8         Atuona      PF     76.89  -9.8000 -139.0333
# 9           Sann      PK     82.38  26.0418   68.1378
# 11          Mana      GF     81.23   5.6592  -53.7767
# 15        Faanui      PF     78.12 -16.4833 -151.7500
# 27          Daru      PG     79.57  -9.0763  143.2092
# 28  Texistepeque      SV     88.97  14.1333  -89.5000
# 31         Kapaa      US     82.38  22.0752 -159.3190

# %% [markdown]
# #### Retrieve Hotels from a Nearby Search

# %%
#Set Parameters for a Hotel nearby
# Set the parameters to search for a hotel in Paris.
params = {
    "radius": 5000,
    "types": "lodging",
    "key": g_key,
    "location": "48.8566, 2.3522"}

# %%
# Use base URL to search for hotels in Paris.
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# %%
# Make request and get the JSON data from the search.
hotels = requests.get(base_url, params=params).json()

hotels
# Out:
# {'html_attributions': [],
#  'next_page_token': 'AcYSjRj5Nho6xBR6lk2ISiel2lJu2K9jf9_JT2wTkbbO6uUI2aVWHBnEUhlO6iKy4kbu8lukO1IRKiPqU21OrX-0A7oANSiSk1B1uU89GVQZ4jKilk_iMK_zDmAPSHLDdZ6PyN7eYeBhV6AA5mLZlC0c0SRS5p7_bQ83Q5n1MhbrvL0GAC5bJUtwQUF6Z3I4U5HsRqAApApLwZ53I0I8m0rlnD4WUOcc31NogGEcJViv4WdM_CeLUZFo_rkWnUEpG0aR0IZlmeoSG2aKkzzeQWI4kj64WOELy0jBhMQZL8eWV_PH3QrXrU5QHU9PZjg1d7IilEzioFicq_xdZcraKa6MV7UEorXEPsLwaAnkpeDadmyiEvh3vxwna4BrQgMJ2Tl02cyExtbL9aatMEFbSBVFFSf2n8x0ho93IxynRBhcV44kIFGpwagh4y16',
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8581126, 'lng': 2.3529277},
#     'viewport': {'northeast': {'lat': 48.8594360302915,
#       'lng': 2.354355480291502},
#      'southwest': {'lat': 48.8567380697085, 'lng': 2.351657519708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
# ...

# %%
#Retrieve all the hotels in the results dictionary 
len(hotels["results"])
# Out:
# 20

# %%
#Name of the first hotel
hotels["results"][0]["name"]
# Out:
# 'Hôtel Duo'

# %% [markdown]
# #### Iterate Through hotel_df DataFrame

# %%
#Perform iteration by providing index, row and for loop and iterate through the DataFrame
for index, row in hotel_df.iterrows():
    # Get the latitude and longitude.
    lat = row["Lat"]
    lng = row["Lng"]

    # Add the latitude and longitude to location key for the params dictionary.
    params["location"] = f"{lat},{lng}"

    # Use the search term: "lodging" and our latitude and longitude.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    # Make request and get the JSON data from the search.
    hotels = requests.get(base_url, params=params).json()
    # Grab the first hotel from the results and store the name.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print("Hotel not found... skipping.")
# Out:
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.

# %%
hotel_df.head(10)
# Out:
#             City Country  Max Temp      Lat       Lng  \
# 0      Hithadhoo      MV     80.98  -0.6000   73.0833
# 2       Victoria      HK     77.05  22.2855  114.1577
# 5          Praya      CV     79.34  14.9215  -23.5087
# 8         Atuona      PF     76.89  -9.8000 -139.0333
# 9           Sann      PK     82.38  26.0418   68.1378
# 11          Mana      GF     81.23   5.6592  -53.7767
# 15        Faanui      PF     78.12 -16.4833 -151.7500
# 27          Daru      PG     79.57  -9.0763  143.2092
# 28  Texistepeque      SV     88.97  14.1333  -89.5000
# 31         Kapaa      US     82.38  22.0752 -159.3190
#
#                              Hotel Name
# 0                     Scoop Guest House
# 2                          Mini Central
# 5                         LT Aparthotel
# 8                           Villa Enata
# 9                     New Sindhri Hotel
# 11                            LE SAMANA
# 15   Bora-Bora Pearl Beach Resort & Spa
# 27                           Daru Lodge
# ...

# %% [markdown]
# # Create a Max Temp HeatMap from a Hotel DataFrame

# %%
# Add a heatmap of temperature for the vacation spots.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp, dissipating=False,
             max_intensity=300, point_radius=4)
fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#Adding Markers to the cities on the HeatMap
# Add a heatmap of temperature for the vacation spots and marker for each city.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,
             dissipating=False, max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#<d1> is a description list, <dt> tag is a term in a description list that is nested under the <d1> tag
#dd tag is used to define the term or name or <dt>
info_box_template = """

<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]

# %%
# Add a heatmap of temperature for the vacation spots and a pop-up marker for each city.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
